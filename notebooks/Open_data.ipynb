# %%
import pandas as pd

# %%
test = pd.read_json('../../data/test.json', lines=True)

# %%
test.head()
# Out:
#                                 _id    _timestamp  \
# 0  https://geektimes.ru/post/87455/  1.493199e+09
# 1  https://geektimes.ru/post/87452/  1.493199e+09
# 2  https://geektimes.ru/post/87459/  1.493199e+09
# 3  https://habrahabr.ru/post/87461/  1.493199e+09
# 4   https://habrahabr.ru/post/5754/  1.493193e+09
#
#                                               author  \
# 0  {u'url': u'https://geektimes.ru/users/Timursan...
# 1  {u'url': u'https://geektimes.ru/users/da3mon',...
# 2  {u'url': u'https://geektimes.ru/users/Tutufa',...
# 3  {u'url': u'https://habrahabr.ru/users/easyman'...
# 4  {u'url': u'https://habrahabr.ru/users/Mio', u'...
#
#                                              content        domain flags  \
# 0  <img src="https://habrastorage.org/getpro/geek...  geektimes.ru    []
# 1  Здравствуйте, сообщество!<br>\r\n<br>\r\nТак у...  geektimes.ru    []
# 2                                                     geektimes.ru    []
# ...
